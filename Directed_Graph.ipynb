# %%
import numpy as np
import matplotlib.pyplot as plt
import csv 
from pandas import DataFrame
import networkx as nx
outfile = open('metricsdirected.csv', 'w', newline='')
writer = csv.DictWriter(outfile, fieldnames = ["Dataset","Number of Nodes","Numbber of Edges","AVG:DEGREE","SD:Degree","AVG:INDEGREE", "STD:INDEGREE","AVG:OUTDEGREE","STD:OUTDEGREE","StrongConnection","WeakConnection","AVGConnection","Flow Hirarchy","Average Node Connectivity","AVG Degree Connectivity","SD Degree Connecvivity ","Average Degree connectivity","Average Clustering Coieficinent"])
writer.writeheader()
filenames=open("names.txt", "r")
for line in filenames: 
    name=line.strip()
    S=name
    print(S)

    
 
    infile=open(S, "r")
    flag=0
    u = 0
    final_list = []
    H = nx.DiGraph()
    G = nx.Graph()
    for line in infile:
        line=line.strip()
        line2 = line.split()
        #print(line)
        if flag==0 and line == "*Matrix":
            flag=1
            u = -1
        elif flag ==1:
            final_list.append(line) #Saving the matrix into list
            #print(line2)
            for v in range(len(line2)):
                #print("testing",v,line2[v])
                if line2[v] == '1':
                    #print("That's U & V",u,v)
                    H.add_edge(u,int(v))
        u=u+1
            #print("line is part of graph", line) # adjacencies - add edges.
    #print(type(final_list))    
    
    #my_array = np.array(final_list)
    #For number of nodes
    a = []
    Node = nx.number_of_nodes(H)
    print(Node)
    a.append(Node)
    
    b = []
    Edge = str(nx.number_of_edges(H))
    print(Edge)
    b.append(Edge)
    #print(b)
    #FOR DEGREE
    c =[] 
    deg = nx.degree(H)
    for key,value in deg:
        c.append(value)
    print((c))
    print(np.average(c))
    print(np.std(c))
        
    #For In Degree centrality
    IND = nx.in_degree_centrality(H)
    #print(IND)
    d = [] 
    for key,value in IND.items():
        d.append(value)
        #print(value)
    #FOR OUT DEGREE CENTRALITY    
    OUD = nx.out_degree_centrality(H)
    e = [] 
    for key,value in OUD.items():
        e.append(value)
        #print(b)
        
    f = []
    isit = nx.is_strongly_connected(H)
    f.append(isit)
    
    g = []
    isit2 = nx.is_weakly_connected(H)
    g.append(isit2)
    
    h = []
    isit3 = nx.is_semiconnected(H)
    h.append(isit3)
    #nx.draw(H)
    
    j = []
    flow = nx.flow_hierarchy(H)
    j.append(flow)
    plt.show()
    
    k = [] 
    NC = nx.average_node_connectivity(H)
    k.append(NC)
    #for key,value in NC.items():
    
    l = []
    DC = nx.average_degree_connectivity(H)
    for key,value in DC.items():
        l.append(value)
    print(type(DC))
    
    o = []
    CC = nx.average_clustering(H)
    o.append(CC)
    
    
    n = []
    D = nx.density(H)
    n.append(H)
    print(n)
    

    
    for i in range(10):
        plt.savefig("Graph" + str(i) + ".jpg")
        #print(a)
        #print(b)
        
        
    
    AVGD = str(np.average(c))
    print("CLUSCOIEF",str(o))
    SDD = str(np.std(c))
    INDSD = str(np.std(d))
    INDAVG = str(np.average(d))
    OUDSD = str(np.average(d))
    OUDAVG = str(np.average(d))
    #NCSD = str(np.average(h))
    #NCAVG = str(np.std(h))
    AVGCC = str(np.average(l))
    SDCC = str(np.std(l))
    
    nx.draw(H)
    #df = DataFrame (my_array)
    S = S + ","+str(Node)+","+Edge+","+AVGD+","+SDD+","+INDAVG+","+INDSD+","+OUDAVG+","+OUDSD+","+str(isit)+","+str(isit2)+","+str(isit3)+","+str(j)+","+str(k)+","+AVGCC+","+SDCC+","+str(o)+","+str(n)+","
    
    S= S+ "\n"
    outfile.write(S)
    
filenames.close()
outfile.close()
# Out:
# Chesapeakbay.net
# 36
# 531
# [34, 41, 40, 34, 34, 40, 41, 41, 37, 24, 24, 23, 40, 40, 40, 39, 40, 39, 10, 10, 27, 10, 10, 24, 24, 37, 24, 24, 24, 13, 20, 22, 34, 41, 41, 16]
# 29.5
# 10.644508234557177
# <class 'dict'>
# ...
# CLUSCOIEF [0.53015752669047]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-1-8b442dadf90f> in <module>
#     135     SDCC = str(np.std(l))
#     136
# --> 137     nx.draw(H)
#     138     #df = DataFrame (my_array)
# ...
